# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transaction & fraudulent transaction
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # This dataset is highly imbalence

# %% [markdown]
# # 0 --> Normal transaction

# %% [markdown]
# # 1 --> Fraudulent transaction

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
#Statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # under-sampling
# Build a sample dataset containing similar distribution of normal transactions and fraudulent transactions

# %% [markdown]
# Number of fraudulent transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# # Concatenating two DataFrames

# %%
new_df = pd.concat([legit_sample, fraud], axis=0)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 56504    47459.0 -2.906836 -0.754622  0.110357 -3.240724 -0.751653 -0.477397
# 142341   84655.0  1.264144 -0.641146  0.509117 -0.457159 -1.373556 -1.225245
# 38880    39598.0  0.995592  0.107192 -0.215575  1.079907  0.367944  0.112820
# 159919  113034.0  1.738865 -0.311541  1.061310  4.150908 -0.720445  1.745213
# 231861  146955.0 -0.110125  0.607197 -0.198270 -0.318508  0.630000 -1.175306
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 56504   0.048056  0.099061  0.600195  ... -0.394663 -0.237225 -1.105039
# 142341 -0.403971 -0.240421 -0.806621  ... -0.439032 -0.946760  0.141705
# 38880   0.370522  0.076452 -0.560166  ...  0.151460  0.331933 -0.157341
# 159919 -1.300310  0.472652  0.905386  ...  0.075617  0.664964  0.051122
# 231861  1.096270 -0.272780 -0.006720  ...  0.414735  1.331917  0.017248
#
# ...

# %%
new_df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92681.451220  0.143597 -0.041750  0.064781  0.027758 -0.068761
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.017123 -0.022944 -0.001337  0.045758  ... -0.048271 -0.036657
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.032714  0.002377  0.040704  0.000986 -0.009252 -0.018381 -0.017460
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       80.669045
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Splitting the data into Features & Targets

# %%
X= new_df.drop(columns='Class', axis=1)
Y= new_df['Class']

# %%
Y
# Out:
# 56504     0
# 142341    0
# 38880     0
# 159919    0
# 231861    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# # Split the data into training & testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# # Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the LogesticRegression model with training data
model.fit(X_train, Y_train)
# Out:
# C:\Users\alams\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# accuracy Score

# %%
#accuracy on training data
#the prediction values which the model predicts will stored here
X_train_prediction = model.predict(X_train) 
#The original data and predicted data are compared and the accuracy scored is calculated
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score on training data : ',training_data_accuracy)
# Out:
# Accuracy score on training data :  0.9542566709021602

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data : ',test_data_accuracy)
# Out:
# Accuracy score on test data :  0.9390862944162437

# %% [markdown]
# # Presision

# %%
from sklearn.metrics import precision_score

# %%
#Precision for training data predictions
precision_train = precision_score(Y_train, X_train_prediction)
print('training data Precision =', precision_train)
# Out:
# training data Precision = 0.9811827956989247

# %%
#Precision for test data predictions
precision_test = precision_score(Y_test, X_test_prediction)
print('test data Precision =', precision_test)
# Out:
# test data Precision = 0.9574468085106383

# %% [markdown]
# # Recall

# %%
from sklearn.metrics import recall_score

# %%
#Recall for training data predictions
recall_train = recall_score(Y_train, X_train_prediction)
print('training data recall =', recall_train)
# Out:
# training data recall = 0.9263959390862944

# %%
#Recall for test data predictions
recall_test = recall_score(Y_test, X_test_prediction)
print('test data Recall =', recall_test)
# Out:
# test data Recall = 0.9183673469387755

# %%
from sklearn.metrics import f1_score

# %%
#F1 for training data predictions
f1_train = f1_score(Y_train, X_train_prediction)
print('training data f1 =', f1_train)
# Out:
# training data f1 = 0.9530026109660574

# %%
#F1 for test data predictions
f1_test = f1_score(Y_test, X_test_prediction)
print('test data f1 =', f1_test)
# Out:
# test data f1 = 0.9375000000000001

# %% [markdown]
# # Precission, Recall & F1 Score- Function

# %%
def precision_recall_f1_score(true_labels, pred_labels):
    precision_value = precision_score(true_labels, pred_labels)
    recall_value = recall_score(true_labels, pred_labels)
    f1_score_value = f1_score(true_labels, pred_labels)
    
    print('Precision =',precision_value)
    print('recall =',recall_value)
    print('F1 score =',f1_score_value)

# %%
# classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# Out:
# Precision = 0.9811827956989247
# recall = 0.9263959390862944
# F1 score = 0.9530026109660574

# %%
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision = 0.9574468085106383
# recall = 0.9183673469387755
# F1 score = 0.9375000000000001
